# %% [markdown]
# Imoprts

# %%
import tensorflow as tf
from tensorflow import keras
import numpy as np
import matplotlib.pyplot as plt
import os

# %% [markdown]
# # Hyperparameters

# %%
epochs = 30
nodes_per_layer = [1024,512,256,128,64]
nodes_per_layer = [2000]
nodes_per_layer = [1024,512,256,128,64]


layers = []
batch_size = 64
dropout_rate = 0.3
num_classes = 10

# %% [markdown]
# # Loading and Standerdizing data

# %% [markdown]
# Loading data

# %%
(x_train, y_train), (x_test, y_test) = keras.datasets.cifar10.load_data()

# %% [markdown]
# Standerdizing the images

# %%
x_train = tf.map_fn(lambda image: tf.image.per_image_standardization(image), x_train, dtype=tf.float32)
x_test = tf.map_fn(lambda image: tf.image.per_image_standardization(image), x_test, dtype=tf.float32)

# %% [markdown]
# # Making and Compiling the Model

# %% [markdown]
# I am currently not using l2 regularization because it makes learning with generated data slower and doesn't reduce overfitting

# %%
layers = []
layers.append(tf.keras.layers.Flatten())
for nodes in nodes_per_layer:
 layers.append(keras.layers.Dense(nodes, activation=tf.nn.relu)) # Using l2 regularization kernel_regularizer=tf.keras.regularizers.l2(l=0.0001)
 layers.append(keras.layers.Dropout(dropout_rate))
layers.append(keras.layers.Softmax())
model = keras.Sequential(layers)

# %% [markdown]
# Compiling the model

# %%
model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.001), 
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# %% [markdown]
# # Training the Model

# %% [markdown]
# ## First: without data augmentation
#
# This training is fast and gets the model to around 50%, however it starts overfitting after that which is why we switch to training on generated data which is slower, but less likely to cause overfitting

# %%
overfitting_hist = model.fit(x_train, y_train,epochs=50,batch_size=64,validation_data=(x_test,y_test),use_multiprocessing=True)
# Out:
# Epoch 1/50
# 782/782 [==============================] - 43s 54ms/step - loss: 4.2089 - accuracy: 0.3073 - val_loss: 3.4137 - val_accuracy: 0.3159
# Epoch 2/50
# 782/782 [==============================] - 43s 55ms/step - loss: 4.1507 - accuracy: 0.3063 - val_loss: 3.3502 - val_accuracy: 0.3164
# Epoch 3/50
# 782/782 [==============================] - 42s 54ms/step - loss: 4.1151 - accuracy: 0.3069 - val_loss: 3.2761 - val_accuracy: 0.3171
# Epoch 4/50
# 782/782 [==============================] - 42s 54ms/step - loss: 4.1076 - accuracy: 0.3052 - val_loss: 3.2517 - val_accuracy: 0.3304
# Epoch 5/50
# 782/782 [==============================] - 42s 54ms/step - loss: 4.0980 - accuracy: 0.3058 - val_loss: 3.2730 - val_accuracy: 0.3254
# Epoch 6/50
# 782/782 [==============================] - 43s 55ms/step - loss: 4.0727 - accuracy: 0.3105 - val_loss: 3.2125 - val_accuracy: 0.3198
# Epoch 7/50
# 782/782 [==============================] - 43s 55ms/step - loss: 4.0953 - accuracy: 0.3051 - val_loss: 3.2231 - val_accuracy: 0.3123
# Epoch 8/50
# 782/782 [==============================] - 43s 55ms/step - loss: 4.0968 - accuracy: 0.3046 - val_loss: 3.2357 - val_accuracy: 0.3211
# Epoch 9/50
# 782/782 [==============================] - 42s 54ms/step - loss: 4.1271 - accuracy: 0.3006 - val_loss: 3.2872 - val_accuracy: 0.2880
# Epoch 10/50
# 782/782 [==============================] - 41s 52ms/step - loss: 4.2285 - accuracy: 0.2917 - val_loss: 3.2396 - val_accuracy: 0.2858
# Epoch 11/50
# 782/782 [==============================] - 40s 52ms/step - loss: 4.2891 - accuracy: 0.2886 - val_loss: 3.3033 - val_accuracy: 0.3046
# Epoch 12/50
# 782/782 [==============================] - 41s 53ms/step - loss: 4.3709 - accuracy: 0.2844 - val_loss: 3.3444 - val_accuracy: 0.2947
# Epoch 13/50
# 782/782 [==============================] - 42s 54ms/step - loss: 4.3808 - accuracy: 0.2834 - val_loss: 3.3095 - val_accuracy: 0.2772
# Epoch 14/50
# 782/782 [==============================] - 42s 54ms/step - loss: 4.4695 - accuracy: 0.2794 - val_loss: 3.2873 - val_accuracy: 0.2697
# Epoch 15/50
# 782/782 [==============================] - 42s 54ms/step - loss: 4.5293 - accuracy: 0.2789 - val_loss: 3.3488 - val_accuracy: 0.2628
# Epoch 16/50
# 782/782 [==============================] - 42s 54ms/step - loss: 4.4784 - accuracy: 0.2836 - val_loss: 3.1900 - val_accuracy: 0.2704
# Epoch 17/50
# 782/782 [==============================] - 42s 54ms/step - loss: 4.4713 - accuracy: 0.2822 - val_loss: 3.1338 - val_accuracy: 0.2997
# Epoch 18/50
# 782/782 [==============================] - 42s 54ms/step - loss: 4.4666 - accuracy: 0.2846 - val_loss: 3.1103 - val_accuracy: 0.2961
# Epoch 19/50
# 782/782 [==============================] - 42s 54ms/step - loss: 4.2855 - accuracy: 0.2945 - val_loss: 3.0113 - val_accuracy: 0.3178
# Epoch 20/50
# 782/782 [==============================] - 42s 54ms/step - loss: 4.1222 - accuracy: 0.3051 - val_loss: 2.9687 - val_accuracy: 0.3194
# Epoch 21/50
# 782/782 [==============================] - 42s 53ms/step - loss: 4.0604 - accuracy: 0.3071 - val_loss: 2.9982 - val_accuracy: 0.3099
# Epoch 22/50
# 782/782 [==============================] - 43s 55ms/step - loss: 4.0401 - accuracy: 0.3121 - val_loss: 3.0322 - val_accuracy: 0.3233
# Epoch 23/50
# 782/782 [==============================] - 43s 55ms/step - loss: 4.0650 - accuracy: 0.3076 - val_loss: 3.1923 - val_accuracy: 0.3136
# Epoch 24/50
# 782/782 [==============================] - 42s 54ms/step - loss: 4.0359 - accuracy: 0.3077 - val_loss: 3.0679 - val_accuracy: 0.3222
# Epoch 25/50
# 782/782 [==============================] - 41s 53ms/step - loss: 4.0648 - accuracy: 0.3039 - val_loss: 3.2452 - val_accuracy: 0.2949
# Epoch 26/50
# 782/782 [==============================] - 41s 52ms/step - loss: 4.0649 - accuracy: 0.3071 - val_loss: 3.1048 - val_accuracy: 0.3213
# Epoch 27/50
# 782/782 [==============================] - 41s 52ms/step - loss: 4.1294 - accuracy: 0.3004 - val_loss: 3.1070 - val_accuracy: 0.3045
# Epoch 28/50
# 782/782 [==============================] - 40s 52ms/step - loss: 4.1508 - accuracy: 0.3012 - val_loss: 3.1720 - val_accuracy: 0.3087
# Epoch 29/50
# 782/782 [==============================] - 41s 52ms/step - loss: 4.2037 - accuracy: 0.2955 - val_loss: 3.2399 - val_accuracy: 0.2734
# Epoch 30/50
# 782/782 [==============================] - 40s 52ms/step - loss: 4.2475 - accuracy: 0.2937 - val_loss: 3.1434 - val_accuracy: 0.2972
# Epoch 31/50
# 782/782 [==============================] - 41s 52ms/step - loss: 4.2923 - accuracy: 0.2900 - val_loss: 3.1810 - val_accuracy: 0.2924
# Epoch 32/50
# 782/782 [==============================] - 40s 51ms/step - loss: 4.3168 - accuracy: 0.2900 - val_loss: 3.4011 - val_accuracy: 0.2635
# Epoch 33/50
# 782/782 [==============================] - 40s 51ms/step - loss: 4.3980 - accuracy: 0.2875 - val_loss: 3.1838 - val_accuracy: 0.2875
# Epoch 34/50
# 782/782 [==============================] - 40s 51ms/step - loss: 4.4023 - accuracy: 0.2865 - val_loss: 3.2035 - val_accuracy: 0.2860
# Epoch 35/50
# 782/782 [==============================] - 40s 51ms/step - loss: 4.3641 - accuracy: 0.2898 - val_loss: 3.1747 - val_accuracy: 0.2899
# Epoch 36/50
# 782/782 [==============================] - 40s 51ms/step - loss: 4.3923 - accuracy: 0.2869 - val_loss: 3.0307 - val_accuracy: 0.3066
# Epoch 37/50
# 782/782 [==============================] - 40s 51ms/step - loss: 4.3364 - accuracy: 0.2932 - val_loss: 3.0787 - val_accuracy: 0.3010
# Epoch 38/50
# 782/782 [==============================] - 39s 50ms/step - loss: 4.2525 - accuracy: 0.2975 - val_loss: 3.0404 - val_accuracy: 0.2987
# Epoch 39/50
# 782/782 [==============================] - 40s 51ms/step - loss: 4.1283 - accuracy: 0.3049 - val_loss: 3.0935 - val_accuracy: 0.3036
# Epoch 40/50
# 782/782 [==============================] - 40s 51ms/step - loss: 4.0421 - accuracy: 0.3145 - val_loss: 3.1815 - val_accuracy: 0.2894
# Epoch 41/50
# 782/782 [==============================] - 40s 51ms/step - loss: 4.0435 - accuracy: 0.3120 - val_loss: 3.0912 - val_accuracy: 0.3220
# Epoch 42/50
# 782/782 [==============================] - 40s 51ms/step - loss: 4.0334 - accuracy: 0.3125 - val_loss: 3.1059 - val_accuracy: 0.3121
# Epoch 43/50
# 782/782 [==============================] - 40s 51ms/step - loss: 4.0794 - accuracy: 0.3097 - val_loss: 3.1410 - val_accuracy: 0.3109
# Epoch 44/50
# 782/782 [==============================] - 40s 51ms/step - loss: 4.0791 - accuracy: 0.3108 - val_loss: 3.2046 - val_accuracy: 0.3013
# Epoch 45/50
# 782/782 [==============================] - 40s 51ms/step - loss: 4.1145 - accuracy: 0.3041 - val_loss: 3.1334 - val_accuracy: 0.3108
# Epoch 46/50
# 782/782 [==============================] - 40s 51ms/step - loss: 4.1400 - accuracy: 0.3040 - val_loss: 3.1281 - val_accuracy: 0.3037
# Epoch 47/50
# 782/782 [==============================] - 40s 51ms/step - loss: 4.1707 - accuracy: 0.3018 - val_loss: 3.1910 - val_accuracy: 0.2958
# Epoch 48/50
# 782/782 [==============================] - 40s 51ms/step - loss: 4.2016 - accuracy: 0.2984 - val_loss: 3.1639 - val_accuracy: 0.2947
# Epoch 49/50
# 782/782 [==============================] - 40s 51ms/step - loss: 4.2096 - accuracy: 0.2980 - val_loss: 3.1850 - val_accuracy: 0.2976
# Epoch 50/50
# 782/782 [==============================] - 40s 51ms/step - loss: 4.2417 - accuracy: 0.2969 - val_loss: 3.2994 - val_accuracy: 0.2535

# %% [markdown]
# Plotting training and test accuracy

# %%
plt.plot(overfitting_hist.history['accuracy'])
plt.plot(overfitting_hist.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
# Out:
# Text(0, 0.5, 'accuracy')

# %%
print(overfitting_hist.history.keys())
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %% [markdown]
# The train accuracy is much higher than the test accuracy (by up to 35%), moreover, the test acuracy is either static or going down, which means that the model badly overfits

# %% [markdown]
# ## Data Generation
#
# Define data generator to generate more diverse data

# %%
datagen = keras.preprocessing.image.ImageDataGenerator(
    featurewise_center=False,
    featurewise_std_normalization=False,
    samplewise_center=False,
    samplewise_std_normalization=False,
    rotation_range=7,
    zoom_range = 0.07,
    width_shift_range=0.15,
    height_shift_range=0.15,
    shear_range = 0.01,
    horizontal_flip=True)

# %% [markdown]
# Initialize variables necessary for data generation

# %%
datagen.fit(x_train)

# %% [markdown]
# ## Second: using data augmentation
#
# Training the model using the generated data to avoid overfitting
# This block can be run repeatedly to get better results

# %%
augmented = datagen.flow(x_train, y_train, batch_size=512,shuffle=True)
hist = model.fit_generator(augmented, epochs=50,validation_data=(x_test,y_test))
# Out:
# C:\Users\andr3\AppData\Local\Temp\ipykernel_31772\2729351549.py:2: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   hist = model.fit_generator(augmented, epochs=50,validation_data=(x_test,y_test))
# Epoch 1/50
# 98/98 [==============================] - 28s 278ms/step - loss: 3.2374 - accuracy: 0.0882 - val_loss: 2.7799 - val_accuracy: 0.0943
# Epoch 2/50
# 98/98 [==============================] - 27s 279ms/step - loss: 3.0271 - accuracy: 0.0862 - val_loss: 2.7121 - val_accuracy: 0.0912
# Epoch 3/50
# 98/98 [==============================] - 27s 279ms/step - loss: 2.9790 - accuracy: 0.0897 - val_loss: 2.6552 - val_accuracy: 0.0662
# Epoch 4/50
# 98/98 [==============================] - 27s 278ms/step - loss: 2.9361 - accuracy: 0.0858 - val_loss: 2.6249 - val_accuracy: 0.0709
# Epoch 5/50
# 98/98 [==============================] - 27s 277ms/step - loss: 2.9076 - accuracy: 0.0911 - val_loss: 2.6058 - val_accuracy: 0.0926
# Epoch 6/50
# 98/98 [==============================] - 27s 278ms/step - loss: 2.8829 - accuracy: 0.0866 - val_loss: 2.5921 - val_accuracy: 0.0898
# Epoch 7/50
# 98/98 [==============================] - 27s 277ms/step - loss: 2.8528 - accuracy: 0.0897 - val_loss: 2.4668 - val_accuracy: 0.1079
# Epoch 8/50
# 98/98 [==============================] - 27s 277ms/step - loss: 2.8372 - accuracy: 0.0917 - val_loss: 2.5246 - val_accuracy: 0.0660
# Epoch 9/50
# 98/98 [==============================] - 27s 277ms/step - loss: 2.8260 - accuracy: 0.0920 - val_loss: 2.4600 - val_accuracy: 0.1171
# Epoch 10/50
# 98/98 [==============================] - 28s 286ms/step - loss: 2.8100 - accuracy: 0.0928 - val_loss: 2.4009 - val_accuracy: 0.0840
# Epoch 11/50
# 98/98 [==============================] - 29s 291ms/step - loss: 2.7859 - accuracy: 0.0951 - val_loss: 2.3437 - val_accuracy: 0.0944
# Epoch 12/50
# 98/98 [==============================] - 29s 298ms/step - loss: 2.7829 - accuracy: 0.0946 - val_loss: 2.2957 - val_accuracy: 0.0904
# Epoch 13/50
# 98/98 [==============================] - 28s 288ms/step - loss: 2.7520 - accuracy: 0.0969 - val_loss: 2.3021 - val_accuracy: 0.0941
# Epoch 14/50
# 98/98 [==============================] - 28s 285ms/step - loss: 2.7531 - accuracy: 0.0958 - val_loss: 2.2771 - val_accuracy: 0.0851
# Epoch 15/50
# 98/98 [==============================] - 28s 287ms/step - loss: 2.7338 - accuracy: 0.0963 - val_loss: 2.2309 - val_accuracy: 0.0867
# Epoch 16/50
# 98/98 [==============================] - 28s 288ms/step - loss: 2.7210 - accuracy: 0.0984 - val_loss: 2.1765 - val_accuracy: 0.0820
# Epoch 17/50
# 98/98 [==============================] - 28s 282ms/step - loss: 2.7256 - accuracy: 0.0992 - val_loss: 2.1482 - val_accuracy: 0.0947
# Epoch 18/50
# 98/98 [==============================] - 29s 298ms/step - loss: 2.7129 - accuracy: 0.0986 - val_loss: 2.1821 - val_accuracy: 0.0942
# Epoch 19/50
# 98/98 [==============================] - 29s 292ms/step - loss: 2.6939 - accuracy: 0.0990 - val_loss: 2.1749 - val_accuracy: 0.0956
# Epoch 20/50
# 98/98 [==============================] - 29s 297ms/step - loss: 2.6926 - accuracy: 0.1011 - val_loss: 2.1218 - val_accuracy: 0.0923
# Epoch 21/50
# 98/98 [==============================] - 29s 291ms/step - loss: 2.6877 - accuracy: 0.0968 - val_loss: 2.1302 - val_accuracy: 0.0880
# Epoch 22/50
# 98/98 [==============================] - 28s 288ms/step - loss: 2.6834 - accuracy: 0.0977 - val_loss: 2.1255 - val_accuracy: 0.0912
# Epoch 23/50
# 98/98 [==============================] - 29s 295ms/step - loss: 2.6833 - accuracy: 0.0946 - val_loss: 2.0685 - val_accuracy: 0.0955
# Epoch 24/50
# 98/98 [==============================] - 30s 304ms/step - loss: 2.6697 - accuracy: 0.0998 - val_loss: 2.0959 - val_accuracy: 0.0950
# Epoch 25/50
# 98/98 [==============================] - 28s 284ms/step - loss: 2.6592 - accuracy: 0.1024 - val_loss: 2.0203 - val_accuracy: 0.0928
# Epoch 26/50
# 98/98 [==============================] - 28s 283ms/step - loss: 2.6701 - accuracy: 0.1017 - val_loss: 2.0453 - val_accuracy: 0.0880
# Epoch 27/50
# 98/98 [==============================] - 29s 296ms/step - loss: 2.6576 - accuracy: 0.0992 - val_loss: 2.0641 - val_accuracy: 0.1153
# Epoch 28/50
# 98/98 [==============================] - 28s 290ms/step - loss: 2.6514 - accuracy: 0.1022 - val_loss: 2.0330 - val_accuracy: 0.0835
# Epoch 29/50
# 98/98 [==============================] - 34s 349ms/step - loss: 2.6460 - accuracy: 0.1050 - val_loss: 2.0090 - val_accuracy: 0.0911
# Epoch 30/50
# 98/98 [==============================] - 43s 439ms/step - loss: 2.6461 - accuracy: 0.1021 - val_loss: 2.0313 - val_accuracy: 0.0921
# Epoch 31/50
# 98/98 [==============================] - 37s 380ms/step - loss: 2.6414 - accuracy: 0.1006 - val_loss: 2.0077 - val_accuracy: 0.0955
# Epoch 32/50
# 98/98 [==============================] - 39s 402ms/step - loss: 2.6507 - accuracy: 0.1014 - val_loss: 2.0379 - val_accuracy: 0.1055
# Epoch 33/50
# 98/98 [==============================] - 38s 385ms/step - loss: 2.6418 - accuracy: 0.1025 - val_loss: 2.0008 - val_accuracy: 0.0891
# Epoch 34/50
# 98/98 [==============================] - 36s 370ms/step - loss: 2.6411 - accuracy: 0.1018 - val_loss: 2.0031 - val_accuracy: 0.0995
# Epoch 35/50
# 98/98 [==============================] - 38s 383ms/step - loss: 2.6266 - accuracy: 0.1019 - val_loss: 2.0142 - val_accuracy: 0.0977
# Epoch 36/50
# 98/98 [==============================] - 37s 379ms/step - loss: 2.6263 - accuracy: 0.1015 - val_loss: 2.0372 - val_accuracy: 0.0898
# Epoch 37/50
# 98/98 [==============================] - 39s 399ms/step - loss: 2.6348 - accuracy: 0.0999 - val_loss: 1.9868 - val_accuracy: 0.0890
# Epoch 38/50
# 98/98 [==============================] - 39s 399ms/step - loss: 2.6266 - accuracy: 0.0998 - val_loss: 2.0215 - val_accuracy: 0.0827
# Epoch 39/50
# 98/98 [==============================] - 59s 599ms/step - loss: 2.6070 - accuracy: 0.1023 - val_loss: 1.9631 - val_accuracy: 0.0971
# Epoch 40/50
# 98/98 [==============================] - 58s 594ms/step - loss: 2.6194 - accuracy: 0.1036 - val_loss: 1.9681 - val_accuracy: 0.0913
# Epoch 41/50
# 98/98 [==============================] - 60s 608ms/step - loss: 2.6153 - accuracy: 0.1010 - val_loss: 2.0154 - val_accuracy: 0.0867
# Epoch 42/50
# 98/98 [==============================] - 49s 493ms/step - loss: 2.6172 - accuracy: 0.1033 - val_loss: 1.9803 - val_accuracy: 0.0870
# Epoch 43/50
# 98/98 [==============================] - 50s 507ms/step - loss: 2.6255 - accuracy: 0.1036 - val_loss: 1.9812 - val_accuracy: 0.0964
# Epoch 44/50
# 98/98 [==============================] - 50s 509ms/step - loss: 2.6126 - accuracy: 0.1045 - val_loss: 1.9387 - val_accuracy: 0.0874
# Epoch 45/50
# 98/98 [==============================] - 48s 494ms/step - loss: 2.6030 - accuracy: 0.1015 - val_loss: 1.9476 - val_accuracy: 0.0796
# Epoch 46/50
# 98/98 [==============================] - 46s 466ms/step - loss: 2.6080 - accuracy: 0.0999 - val_loss: 1.9707 - val_accuracy: 0.0961
# Epoch 47/50
# 98/98 [==============================] - 42s 428ms/step - loss: 2.6017 - accuracy: 0.1032 - val_loss: 1.9282 - val_accuracy: 0.0897
# Epoch 48/50
# 98/98 [==============================] - 43s 434ms/step - loss: 2.6058 - accuracy: 0.1014 - val_loss: 1.9577 - val_accuracy: 0.1110
# Epoch 49/50
# 98/98 [==============================] - 45s 462ms/step - loss: 2.5848 - accuracy: 0.1047 - val_loss: 1.9352 - val_accuracy: 0.0921
# Epoch 50/50
# 98/98 [==============================] - 53s 539ms/step - loss: 2.5962 - accuracy: 0.1030 - val_loss: 1.9396 - val_accuracy: 0.0925

# %% [markdown]
# Plotting accuracy curve

# %%
plt.plot(hist.history['accuracy'])
plt.plot(hist.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
# Out:
# Text(0, 0.5, 'accuracy')

# %% [markdown]
# In the beginning, the test accuracy is better than the training accuracy, but after the first epochs the train accuracy gets higher than the test accuracy by only up to 4% which means that the model does not worriyingly overfit

# %% [markdown]
# ## Evaluate the Model

# %%
test_loss, test_acc = model.evaluate(x_test, y_test)
print('Test accuracy:', test_acc)
# Out:
# 10000/10000 [==============================] - 1s 94us/step
# Test accuracy: 0.6424

# %% [markdown]
# # Takeaway
#
# ### On the one hand
# Training using the unaugmented data set wuickly results in overfitting
# ### On the other hand
# Using the augmented data set right away causes undefitting
# ### Therefore
# The best approach that I came up with is to train using unaugmented data first until that results in overfitting and then to switch to augmented data. The model has less of a hard time training on augmented data because it has already leared many of the main features of the classes before data augmentation makes learning harder but less prone to overfitting.
